# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import nltk
nltk.download('punkt')
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("peristiwa_sejarah.json").read()
intents = json.loads(data_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kyrif\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 2. Data pre-processing

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kyrif\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 72 documents
# 33 classes ['Ambarawa', 'Ambarawa1', 'Ambarawa2', 'Bandung_lautan_api', 'Bandung_lautan_api1', 'Bandung_lautan_api2', 'Organisasi_Budi_Utomo', 'Organisasi_Budi_Utomo1', 'Organisasi_Budi_Utomo2', 'Peristiwa_Rengasdengklok', 'Peristiwa_Rengasdengklok1', 'Peristiwa_Rengasdengklok2', 'Surat_Kabar_Sin_Po ', 'Surat_Kabar_Sin_Po1', 'g30spki', 'g30spki2', 'g30spki3', 'g30spki4', 'goodbye', 'greeting', 'proklamasi', 'sejarah', 'tokoh_g30spki1', 'tokoh_g30spki2', 'tokoh_g30spki3', 'tokoh_g30spki4', 'tokoh_g30spki5', 'tokoh_g30spki6', 'tokoh_g30spki7', 'tokoh_pencipta_lagu', 'tokoh_pengibar_bendera', 'tokoh_penjahit_bendera', 'tokoh_penulis_naskah']
# 111 unique lemmatized words ['3', '30', 'adalah', 'ahmad', 'ambarawa', 'apa', 'api', 'bagaimana', 'bandung', 'banyak', 'belakang', 'bendera', 'berapa', 'berdiri', 'berdirinya', 'budi', 'dalam', 'dari', 'dimaksud', 'dimana', 'donal', 'fungsi', 'g30s', 'gerakan', 'golongan', 'hai', 'halo', 'haryono', 'indonesia', 'isaac', 'itu', 'jendral', 'jumpa', 'kabar', 'kali', 'kapan', 'kapten', 'kasih', 'kemerdekaan', 'kenapa', 'korban', 'lagu', 'latar', 'lautan', 'letjen', 'ma', 'makna', 'mayjen', 'menculik', 'mengapa', 'mengibarkan', 'menjadi', 'merah', 'muda', 'naskah', 'organisasi', 'pagi', 'pandjaitan', 'parman', 'pemuda', 'pencipta', 'penculikan', 'pendiri', 'pengertian', 'penggagas', 'penjahit', 'penulis', 'peran', 'perang', 'peristiwa', 'pertama', 'pertempuran', 'pertempurang', 'pierre', 'pki', 'po', 'proklamasi', 'putih', 'raden', 'raya', 'rengasdengklok', 's', 's.parman', 'saja', 'sampai', 'sejarah', 'selamat', 'september', 'siang', 'siapa', 'sin', 'siswomiharjo', 'suprapto', 'surat', 'sutoyo', 'tahun', 'tanggal', 'teks', 'tendean', 'terima', 'terjadi', 'terjadinya', 'terlibat', 'tinggal', 'tirtodarmo', 'tokoh', 'tua', 'tujuan', 'utomo', 'yang', 'yani']

# %% [markdown]
# # 3. Creating Training Data
#
# - Pada dasarnya, bag of words adalah representasi sederhana dari setiap teks dalam sebuah kalimat sebagai bag of words-nya.

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# # 5. Creating Modeling
#
# - Pada proses ini kami akan membuat model jaringan saraf dan menyimpan model tersebut

# %%
from tensorflow.keras.optimizers import SGD
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(256, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

from tensorflow.keras.optimizers import SGD

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('models.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 15/15 [==============================] - 2s 4ms/step - loss: 3.4721 - accuracy: 0.0556
# Epoch 2/200
# 15/15 [==============================] - 0s 4ms/step - loss: 3.4917 - accuracy: 0.0694
# Epoch 3/200
# 15/15 [==============================] - 0s 5ms/step - loss: 3.3730 - accuracy: 0.0833
# Epoch 4/200
# 15/15 [==============================] - 0s 4ms/step - loss: 3.3262 - accuracy: 0.1389
# Epoch 5/200
# 15/15 [==============================] - 0s 4ms/step - loss: 3.2058 - accuracy: 0.1111
# Epoch 6/200
# 15/15 [==============================] - 0s 5ms/step - loss: 3.1629 - accuracy: 0.1389
# Epoch 7/200
# 15/15 [==============================] - 0s 5ms/step - loss: 3.0485 - accuracy: 0.2083
# Epoch 8/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.9691 - accuracy: 0.1944
# Epoch 9/200
# 15/15 [==============================] - 0s 6ms/step - loss: 2.8372 - accuracy: 0.2083
# Epoch 10/200
# 15/15 [==============================] - 0s 4ms/step - loss: 2.6918 - accuracy: 0.3194
# Epoch 11/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.6549 - accuracy: 0.2361
# Epoch 12/200
# 15/15 [==============================] - 0s 4ms/step - loss: 2.6312 - accuracy: 0.2083
# Epoch 13/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.5056 - accuracy: 0.3750
# Epoch 14/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.4649 - accuracy: 0.2639
# Epoch 15/200
# 15/15 [==============================] - 0s 4ms/step - loss: 2.2107 - accuracy: 0.3472
# Epoch 16/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.2863 - accuracy: 0.3611
# Epoch 17/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.3120 - accuracy: 0.3333
# Epoch 18/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.2097 - accuracy: 0.3611
# Epoch 19/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.1459 - accuracy: 0.3472
# Epoch 20/200
# 15/15 [==============================] - 0s 5ms/step - loss: 2.0546 - accuracy: 0.4306
# Epoch 21/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9571 - accuracy: 0.4306
# Epoch 22/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9127 - accuracy: 0.3889
# Epoch 23/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.8317 - accuracy: 0.4583
# Epoch 24/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.7267 - accuracy: 0.4583
# Epoch 25/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.7466 - accuracy: 0.5000
# Epoch 26/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.6688 - accuracy: 0.4583
# Epoch 27/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.6480 - accuracy: 0.4722
# Epoch 28/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.6666 - accuracy: 0.5278
# Epoch 29/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.7413 - accuracy: 0.4583
# Epoch 30/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.4196 - accuracy: 0.5833
# Epoch 31/200
# 15/15 [==============================] - 0s 8ms/step - loss: 1.5936 - accuracy: 0.5556
# Epoch 32/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.4021 - accuracy: 0.6111
# Epoch 33/200
# 15/15 [==============================] - 0s 7ms/step - loss: 1.3663 - accuracy: 0.5556
# Epoch 34/200
# 15/15 [==============================] - 0s 9ms/step - loss: 1.2066 - accuracy: 0.6389
# Epoch 35/200
# 15/15 [==============================] - 0s 9ms/step - loss: 1.3810 - accuracy: 0.5972
# Epoch 36/200
# 15/15 [==============================] - 0s 10ms/step - loss: 1.6840 - accuracy: 0.5139
# Epoch 37/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.5002 - accuracy: 0.5139
# Epoch 38/200
# 15/15 [==============================] - 0s 7ms/step - loss: 1.2197 - accuracy: 0.6667
# Epoch 39/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1653 - accuracy: 0.5833
# Epoch 40/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.2891 - accuracy: 0.5972
# Epoch 41/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.4007 - accuracy: 0.6389
# Epoch 42/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.2014 - accuracy: 0.6389
# Epoch 43/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1490 - accuracy: 0.5833
# Epoch 44/200
# 15/15 [==============================] - 0s 7ms/step - loss: 1.2000 - accuracy: 0.6667
# Epoch 45/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1011 - accuracy: 0.6667
# Epoch 46/200
# 15/15 [==============================] - 0s 7ms/step - loss: 1.0899 - accuracy: 0.6944
# Epoch 47/200
# 15/15 [==============================] - 0s 10ms/step - loss: 1.1897 - accuracy: 0.6389
# Epoch 48/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.3461 - accuracy: 0.5972
# Epoch 49/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1729 - accuracy: 0.6389
# Epoch 50/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.3486 - accuracy: 0.5694
# Epoch 51/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1815 - accuracy: 0.6806
# Epoch 52/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.2083 - accuracy: 0.5417
# Epoch 53/200
# 15/15 [==============================] - 0s 7ms/step - loss: 1.1837 - accuracy: 0.6250
# Epoch 54/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.3142 - accuracy: 0.6528
# Epoch 55/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8900 - accuracy: 0.7361
# Epoch 56/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0535 - accuracy: 0.6250
# Epoch 57/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.9448 - accuracy: 0.6667
# Epoch 58/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6950 - accuracy: 0.7361
# Epoch 59/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1424 - accuracy: 0.6528
# Epoch 60/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8552 - accuracy: 0.7778
# Epoch 61/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6770 - accuracy: 0.7778
# Epoch 62/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.9103 - accuracy: 0.7778
# Epoch 63/200
# 15/15 [==============================] - 0s 8ms/step - loss: 1.1624 - accuracy: 0.6806
# Epoch 64/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6049 - accuracy: 0.8194
# Epoch 65/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7969 - accuracy: 0.8056
# Epoch 66/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.9163 - accuracy: 0.7361
# Epoch 67/200
# 15/15 [==============================] - 0s 8ms/step - loss: 1.0462 - accuracy: 0.6806
# Epoch 68/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.8039 - accuracy: 0.7639
# Epoch 69/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6138 - accuracy: 0.8194
# Epoch 70/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1278 - accuracy: 0.6806
# Epoch 71/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7860 - accuracy: 0.7778
# Epoch 72/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7734 - accuracy: 0.7639
# Epoch 73/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6174 - accuracy: 0.8333
# Epoch 74/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7854 - accuracy: 0.7500
# Epoch 75/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.9378 - accuracy: 0.7639
# Epoch 76/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8620 - accuracy: 0.7500
# Epoch 77/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.7917
# Epoch 78/200
# 15/15 [==============================] - 0s 11ms/step - loss: 0.8417 - accuracy: 0.7639
# Epoch 79/200
# 15/15 [==============================] - 0s 9ms/step - loss: 1.1487 - accuracy: 0.7083
# Epoch 80/200
# 15/15 [==============================] - 0s 11ms/step - loss: 0.7460 - accuracy: 0.7778
# Epoch 81/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.7817 - accuracy: 0.7500
# Epoch 82/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.9585 - accuracy: 0.7083
# Epoch 83/200
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6661 - accuracy: 0.7917
# Epoch 84/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6277 - accuracy: 0.8194
# Epoch 85/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6201 - accuracy: 0.8472
# Epoch 86/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7852 - accuracy: 0.7361
# Epoch 87/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8637 - accuracy: 0.7500
# Epoch 88/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8241 - accuracy: 0.6944
# Epoch 89/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8195 - accuracy: 0.7083
# Epoch 90/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8313 - accuracy: 0.7917
# Epoch 91/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.9754 - accuracy: 0.7639
# Epoch 92/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4638 - accuracy: 0.8056
# Epoch 93/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8567 - accuracy: 0.7361
# Epoch 94/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6580 - accuracy: 0.7917
# Epoch 95/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6796 - accuracy: 0.7778
# Epoch 96/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4880 - accuracy: 0.8056
# Epoch 97/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6736 - accuracy: 0.8194
# Epoch 98/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7226 - accuracy: 0.7917
# Epoch 99/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5488 - accuracy: 0.8333
# Epoch 100/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8692 - accuracy: 0.7083
# Epoch 101/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.9809 - accuracy: 0.6944
# Epoch 102/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7291 - accuracy: 0.7500
# Epoch 103/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.8472
# Epoch 104/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7349 - accuracy: 0.7917
# Epoch 105/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4977 - accuracy: 0.8333
# Epoch 106/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5666 - accuracy: 0.8056
# Epoch 107/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6193 - accuracy: 0.7917
# Epoch 108/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4061 - accuracy: 0.8750
# Epoch 109/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6862 - accuracy: 0.8333
# Epoch 110/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8362 - accuracy: 0.7639
# Epoch 111/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5413 - accuracy: 0.7917
# Epoch 112/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4828 - accuracy: 0.8056
# Epoch 113/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4299 - accuracy: 0.9028
# Epoch 114/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5630 - accuracy: 0.8472
# Epoch 115/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3980 - accuracy: 0.8750
# Epoch 116/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6058 - accuracy: 0.8333
# Epoch 117/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6255 - accuracy: 0.8056
# Epoch 118/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8356 - accuracy: 0.7500
# Epoch 119/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8218 - accuracy: 0.7361
# Epoch 120/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4810 - accuracy: 0.8472
# Epoch 121/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.7172 - accuracy: 0.7639
# Epoch 122/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6373 - accuracy: 0.8056
# Epoch 123/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.7083 - accuracy: 0.7778
# Epoch 124/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4951 - accuracy: 0.8194
# Epoch 125/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5263 - accuracy: 0.8056
# Epoch 126/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6278 - accuracy: 0.8056
# Epoch 127/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8811 - accuracy: 0.7917
# Epoch 128/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5449 - accuracy: 0.8194
# Epoch 129/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5569 - accuracy: 0.8889
# Epoch 130/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5475 - accuracy: 0.8194
# Epoch 131/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5283 - accuracy: 0.8194
# Epoch 132/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5768 - accuracy: 0.8194
# Epoch 133/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5230 - accuracy: 0.8194
# Epoch 134/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7824 - accuracy: 0.7778
# Epoch 135/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4795 - accuracy: 0.8750
# Epoch 136/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6484 - accuracy: 0.8056
# Epoch 137/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.1701 - accuracy: 0.7500
# Epoch 138/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7397 - accuracy: 0.7778
# Epoch 139/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5876 - accuracy: 0.7917
# Epoch 140/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6217 - accuracy: 0.8056
# Epoch 141/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4566 - accuracy: 0.8472
# Epoch 142/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5406 - accuracy: 0.8472
# Epoch 143/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5947 - accuracy: 0.8194
# Epoch 144/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7082 - accuracy: 0.7778
# Epoch 145/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.9426 - accuracy: 0.7639
# Epoch 146/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7240 - accuracy: 0.7917
# Epoch 147/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4438 - accuracy: 0.8333
# Epoch 148/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4994 - accuracy: 0.8472
# Epoch 149/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4054 - accuracy: 0.8611
# Epoch 150/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6677 - accuracy: 0.8194
# Epoch 151/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5243 - accuracy: 0.8056
# Epoch 152/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7323 - accuracy: 0.8194
# Epoch 153/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7110 - accuracy: 0.8194
# Epoch 154/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.9417 - accuracy: 0.8056
# Epoch 155/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4439 - accuracy: 0.8750
# Epoch 156/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.1705 - accuracy: 0.7778
# Epoch 157/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6966 - accuracy: 0.7778
# Epoch 158/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.8472
# Epoch 159/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5328 - accuracy: 0.8472
# Epoch 160/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5464 - accuracy: 0.8333
# Epoch 161/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5491 - accuracy: 0.7917
# Epoch 162/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7824 - accuracy: 0.8333
# Epoch 163/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6195 - accuracy: 0.7778
# Epoch 164/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8100 - accuracy: 0.7778
# Epoch 165/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5206 - accuracy: 0.8611
# Epoch 166/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7220 - accuracy: 0.8472
# Epoch 167/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8272 - accuracy: 0.8056
# Epoch 168/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7382 - accuracy: 0.8611
# Epoch 169/200
# 15/15 [==============================] - 0s 4ms/step - loss: 1.0277 - accuracy: 0.7778
# Epoch 170/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7144 - accuracy: 0.8333
# Epoch 171/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7141 - accuracy: 0.7917
# Epoch 172/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5768 - accuracy: 0.8333
# Epoch 173/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5346 - accuracy: 0.8333
# Epoch 174/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6571 - accuracy: 0.8194
# Epoch 175/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8226 - accuracy: 0.7778
# Epoch 176/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0953 - accuracy: 0.7778
# Epoch 177/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7612 - accuracy: 0.7639
# Epoch 178/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5292 - accuracy: 0.8333
# Epoch 179/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8634 - accuracy: 0.7778
# Epoch 180/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.0306 - accuracy: 0.7639
# Epoch 181/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0716 - accuracy: 0.6528
# Epoch 182/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.9136 - accuracy: 0.7917
# Epoch 183/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8895 - accuracy: 0.7778
# Epoch 184/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.7504 - accuracy: 0.7917
# Epoch 185/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8764 - accuracy: 0.7778
# Epoch 186/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7847 - accuracy: 0.7639
# Epoch 187/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6411 - accuracy: 0.8333
# Epoch 188/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4230 - accuracy: 0.9028
# Epoch 189/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5186 - accuracy: 0.8333
# Epoch 190/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6556 - accuracy: 0.8333
# Epoch 191/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6392 - accuracy: 0.8056
# Epoch 192/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5773 - accuracy: 0.7917
# Epoch 193/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2974 - accuracy: 0.9028
# Epoch 194/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7257 - accuracy: 0.8194
# Epoch 195/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.9992 - accuracy: 0.7361
# Epoch 196/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.1195 - accuracy: 0.7361
# Epoch 197/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.2618 - accuracy: 0.7917
# Epoch 198/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7042 - accuracy: 0.8194
# Epoch 199/200
# 15/15 [==============================] - 0s 6ms/step - loss: 1.3729 - accuracy: 0.7222
# Epoch 200/200
# 15/15 [==============================] - 0s 5ms/step - loss: 1.2797 - accuracy: 0.6806
#
#
# **************************************************
#
# Model Created Successfully!

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               28672
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 33)                2145
#
# =================================================================
# Total params: 71,969
# Trainable params: 71,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'], label='Accuracy')
plt.plot(hist.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Model Training History')
plt.legend()
plt.show()
